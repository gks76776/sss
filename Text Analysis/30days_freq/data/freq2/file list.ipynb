# %%
from glob import glob
import os

# %%
file_list = glob('./naver*/part-*')

# %%
file_list
# Out:
# ['.\\naver_000640_freq.parquet\\part-00000-2c0e73bd-3251-427a-b438-d2393e66b74b-c000.snappy.parquet',
#  '.\\naver_000670_freq.parquet\\part-00000-2eb09274-6331-4909-82ae-9c2ea515a0c2-c000.snappy.parquet',
#  '.\\naver_005300_freq.parquet\\part-00000-b8a82783-8ea8-463b-bbf2-adc7a406dfe5-c000.snappy.parquet',
#  '.\\naver_005440_freq.parquet\\part-00000-82787f5d-4813-4202-905a-22da6cdff1c7-c000.snappy.parquet',
#  '.\\naver_005490_freq.parquet\\part-00000-29f60172-bcb8-476a-9258-b8e35a9aa47b-c000.snappy.parquet',
#  '.\\naver_005610_freq.parquet\\part-00000-3af17382-6348-4925-9065-262f2615da81-c000.snappy.parquet',
#  '.\\naver_005830_freq.parquet\\part-00000-80a5dfe7-f942-4a75-943b-89f6c84375ef-c000.snappy.parquet',
#  '.\\naver_005850_freq.parquet\\part-00000-57baabe6-7e4d-4851-b5fe-527eeb693b9f-c000.snappy.parquet',
#  '.\\naver_005940_freq.parquet\\part-00000-a80a7a0a-82d2-45a1-9717-b9c409a2840a-c000.snappy.parquet',
# ...

# %%
#현재 폴더의 파일리스트
file_list_a = [file[8:14] for file in file_list]

# %%
file_list_a
# Out:
# ['000640',
#  '000670',
#  '005300',
#  '005440',
#  '005490',
#  '005610',
#  '005830',
#  '005850',
#  '005940',
#  '006120',
#  '006260',
#  '006280',
#  '006360',
#  '006400',
#  '006650',
#  '006800',
#  '006840',
#  '007070',
#  '007310',
#  '007570',
#  '008060',
#  '008560',
#  '008930',
#  '009540',
#  '009830',
#  '010120',
#  '010130',
#  '010620',
#  '010780',
#  '010950',
#  '011070',
#  '011170',
#  '011210',
#  '011780',
#  '011790',
#  '012330',
#  '012630',
#  '012750',
#  '014680',
#  '014820',
#  '014830',
#  '019680',
#  '020000',
#  '021240',
#  '023530',
#  '024110',
#  '025540',
#  '025860',
#  '026960',
#  '027410',
#  '028050',
#  '028670',
#  '029780',
#  '032830',
#  '033780',
#  '033920',
#  '034730',
#  '035250',
#  '036460',
#  '036580',
#  '042670',
#  '047050',
#  '049770',
#  '051600',
#  '051900',
#  '055550',
#  '057050',
#  '060980',
#  '064960',
#  '069260',
#  '069620',
#  '069960',
#  '071050',
#  '071840',
#  '241560',
#  '267250',
# ...

# %%
len(file_list_a)
# Out:
# 81

# %%
# all_list = ["060980",
#  "012750",
#  "020000",
#  "000670",
#  "025540",
#  "057050",
#  "005850",
#  "005830",
#  "298040",
#  "005300",
#  "069260",
#  "014680",
#  "033920",
#  "000640",
#  "064960",
#  "011790",
#  "029780",
#  "008060",
#  "282330",
#  "010130",
#  "006260",
#  "005440",
#  "049770",
#  "241560",
#  "026960",
#  "005610",
#  "034730",
#  "071050",
#  "011780",
#  "007310",
#  "006840",
#  "010780",
#  "010120",
#  "051900",
#  "294870",
#  "006280",
#  "021240",
#  "024110",
#  "006650",
#  "271560",
#  "008560",
#  "069960",
#  "005940",
#  "071840",
#  "285130",
#  "033780",
#  "032830",
#  "010620",
#  "055550",
#  "008930",
#  "035250",
#  "006120",
#  "007070",
#  "036460",
#  "012630",
#  "267250",
#  "007570",
#  "012330",
#  "051600",
#  "014820",
#  "010950",
#  "047050",
#  "011210",
#  "011170",
#  "025860",
#  "023530",
#  "052690",
#  "069620",
#  "006800",
#  "011070",
#  "027410",
#  "028670",
#  "042670",
#  "009540",
#  "009830",
#  "028050",
#  "006400",
#  "012450",
#  "006360",
#  "005490",
#  "047040",
#  "028260",
#  "008770",
#  "009420",
#  "034020",
#  "010140",
#  "010060",
#   "051910",
#  "020150",
#  "016360",
#  "042660",
#  "005380",
#  "009150",
#  "073240",
#  "015760",
#  "017800",
#  "066570",
#  "064350",
#  "047810",
#  "068270",
#  "034220",
#  "000660"]

# %%
# len(all_list)

# %%
# for ele1 in all_list:
#     for ele2 in file_list_a:
#         if ele1 == ele2:
#             all_list.remove(ele1)

# %%
# all_list

# %%
len(all_list)
# Out:
# 68

# %%
volume_list=[]
adjusted_files = []
for file in file_list:
    adjusted_files.append((file[2:],os.path.getsize(file)))
    volume_list.append(os.path.getsize(file))

# %%
sorted_files = sorted(adjusted_files,key=lambda x:x[1],reverse=True)

# %%
sorted_files
# Out:
# [('naver_006360_freq.parquet\\part-00000-c81e0e17-41c9-4ee6-b7d2-2e12ffbecf57-c000.snappy.parquet',
#   17201342),
#  ('naver_005490_freq.parquet\\part-00000-29f60172-bcb8-476a-9258-b8e35a9aa47b-c000.snappy.parquet',
#   16783986),
#  ('naver_006400_freq.parquet\\part-00000-134fb689-200c-41d2-909b-68d0186e2fe1-c000.snappy.parquet',
#   15626746),
#  ('naver_009830_freq.parquet\\part-00000-5355513d-c225-46f5-ab44-e2efb6860bce-c000.snappy.parquet',
#   14700707),
#  ('naver_009540_freq.parquet\\part-00000-d1689c2b-62a1-4179-8184-0bf12e5a8fab-c000.snappy.parquet',
#   13847856),
#  ('naver_028050_freq.parquet\\part-00000-801c12ff-1fb3-4c9f-9565-b9c278b6293b-c000.snappy.parquet',
#   13548302),
#  ('naver_042670_freq.parquet\\part-00000-e905ddf9-98f6-426b-ba44-638433ae4b84-c000.snappy.parquet',
#   13275535),
#  ('naver_011070_freq.parquet\\part-00000-5e6692a1-ad57-4ade-bdd0-0cd6429c550b-c000.snappy.parquet',
#   7921674),
# ...

# %%
code_list = [file[0][6:12] for file in sorted_files]

# %%
code_list
# Out:
# ['006360',
#  '005490',
#  '006400',
#  '009830',
#  '009540',
#  '028050',
#  '042670',
#  '011070',
#  '006800',
#  '027410',
#  '069620',
#  '028670',
#  '023530',
#  '025860',
#  '011170',
#  '011210',
#  '047050',
#  '010950',
#  '014820',
#  '051600',
#  '012330',
#  '007570',
#  '055550',
#  '006120',
#  '007070',
#  '267250',
#  '035250',
#  '036460',
#  '008930',
#  '012630',
#  '032830',
#  '010620',
#  '005940',
#  '285130',
#  '033780',
#  '071840',
#  '069960',
#  '006650',
#  '008560',
#  '271560',
#  '010120',
#  '024110',
#  '051900',
#  '006280',
#  '294870',
#  '071050',
#  '021240',
#  '034730',
#  '005610',
#  '007310',
#  '010780',
#  '241560',
#  '011780',
#  '006260',
#  '026960',
#  '005440',
#  '049770',
#  '282330',
#  '010130',
#  '029780',
#  '006840',
#  '008060',
#  '011790',
#  '000640',
#  '064960',
#  '033920',
#  '005300',
#  '069260',
#  '014680',
#  '005830',
#  '298040',
#  '005850',
#  '057050',
#  '020000',
#  '025540',
#  '012750',
# ...

# %%
# 용량 최상위 코드 
'006360'
