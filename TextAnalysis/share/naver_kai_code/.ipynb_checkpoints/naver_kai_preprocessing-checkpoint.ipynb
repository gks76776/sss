# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt 
# %matplotlib inline
import platform
import khaiii
api = khaiii.KhaiiiApi()
api.open()
import time
import sys
import os
if not sys.modules.get('pyarrow'):
    os.system('pip3 install pyarrow')
import threading
from tqdm import tqdm_notebook

# %%
stock_code = '005380'
#015760
#005380

# %%
#hinix = pd.read_csv('./naver_{0}.csv'.format(stock_code),index_col=False,names=['index','date','mola','id','ip','like','hate','text','reply'])
hinix = pd.read_csv('../crawled_files/naver_{0}.csv'.format(stock_code),index_col=False,names=['date','mola','id','ip','like','hate','text','reply'])

# %%
hinix.head()
# Out:
#                date  mola        id               ip  like  hate  \
# 0  2018.12.19 01:10   118  honb****  182.221.***.201     0     0
# 1  2018.12.19 01:04   130  honb****  182.221.***.201     0     0
# 2  2018.12.19 00:23   159  himr****   211.243.***.88     3     1
# 3  2018.12.19 00:03   165  jupo****   219.250.***.89     1     0
# 4  2018.12.18 23:43   176  honb****  182.221.***.201     3     0
#
#                                                 text  \
# 0                                          0.28퍼 상승중
# 1                                                 폭락
# 2  문빠들이 쓴소리하는 어르신들을 틀딱이라 욕하지만 요즘 20대가 반문재인 세력으로 돌...
# 3  Today is...\r\nThe gap-Sang continues until th...
# 4                                         내일도 불기둥 가자
#
#                                                reply
# 0                                                NaN
# 1                                                 []
# 2  ['아가 다좋은데 뛰어쓰기 좀하자.\n틀딱들 눈 다버리겠다.\n아무리 틀딱이 바보멍...
# 3                                                 []
# 4                                                 []

# %%
#hinix = hinix.reset_index(drop=True)

# %%
# ## tokenizer 연습
# hinix_sample = hinix.iloc[:50,:]

# %%
# hinix_sample.head()

# %%
#sample_result=hinix_sample['text'].apply(lambda x:api.analyze(x))

# %%
#exexe(sample_result)

# %%
# for element in sample_result:
#     for e in element: 
#         print(e)

# %%
# def exexe(data):
#     hinix_text_str = ' '
#     hinix_str = []
#     result = []
#     for text_list in data:        
#         for text in text_list:
#             #마디를 문자열로 변경 
#             str_text = str(text)
#             # +가 있는 마디가 있을수 있기 split으로 list를 담아줌  
#             corpus = str_text[str_text.find('\t')+1:].split(' + ') # 자른걸 원소로 가지도록             
#             print(corpus)
# #             dict_tags = {'NNG':1,'NNP':1,'NNB':1,'VV':1,'VA':1,'VCP':1,'VCN':1,'MM':1,'MAG':1,'IC':1,'JX':1,'SF':1,'SE':1, 'SW':1, 'SN':1,'XPN':1,'SL':1}
            
# #             # 각 list가 원하는 태그인가 아닌가 검증            
# #             for corpus_element in corpus:
# #                 #corpus_element => 형태소 하나하나.
# #                 tag = corpus_element[corpus_element.find('/')+1:]
# # #                 print(tag)
# #                 if tag.find('.')>=0:
# #                     print(corpus_element,tag)
# #                 tmp = dict_tags.get(tag)                
# #                 if tmp !=None:                   
# #                     # 이 text를 text_list가 되도록 리스트에 담는다.
# #                     hinix_str.append(corpus_element)               
# #         # 리스트가 아닌 str을 담아주기 위해 join을 이용한다.
# #         #print(hinix_str)
# #         result.append(hinix_text_str.join(hinix_str))
# #         #hinix_str 초기화 
# #         hinix_str=[]         
# #     return result

# %%
hinix.date = hinix['date'].apply(lambda x:x[:10])

# %%
hinix
# Out:
#              date  mola        id               ip  like  hate  \
# 0      2018.12.19   118  honb****  182.221.***.201     0     0
# 1      2018.12.19   130  honb****  182.221.***.201     0     0
# 2      2018.12.19   159  himr****   211.243.***.88     3     1
# 3      2018.12.19   165  jupo****   219.250.***.89     1     0
# 4      2018.12.18   176  honb****  182.221.***.201     3     0
# 5      2018.12.18   284  syle****   121.136.***.36     9     0
# 6      2018.12.18   340  gray****   58.237.***.228     3     0
# 7      2018.12.18   776  jake****  211.204.***.207     3     1
# 8      2018.12.18  1046  wjwj****    58.225.***.62    34     4
# 9      2018.12.18   763  mavi****   116.127.***.10    17     6
# 10     2018.12.18  1184  psyc****     1.252.***.32    15     3
# 11     2018.12.18  1064  kxor****   175.223.***.18     6     2
# 12     2018.12.18   962  hook****  175.223.***.101    13     4
# 13     2018.12.18  1499  muso****  106.102.***.136     9     5
# 14     2018.12.18   674  busk****    39.113.***.91    26     3
# 15     2018.12.18   625  mavi****   116.127.***.10     9     4
# 16     2018.12.18   939  cck3****   118.35.***.117     4     2
# 17     2018.12.18   911  khan****    115.23.***.45     9     2
# 18     2018.12.18   910  mavi****   116.127.***.10     1     3
# 19     2018.12.18  1269  jsc6****     59.5.***.234     5     7
# 20     2018.12.18   630  midu****   183.102.***.18     3     7
# 21     2018.12.18   748  assa****  121.157.***.238     9    14
# 22     2018.12.18   694  psy6****   49.254.***.118     5    11
# 23     2018.12.18   972  cjmn****   211.59.***.124     9     1
# 24     2018.12.18   836  gksr****   223.38.***.235     2     1
# 25     2018.12.18   997  hc02****     14.36.***.80     5    21
# 26     2018.12.18   825  honb****  182.221.***.201    10     2
# 27     2018.12.18   826  info****  125.142.***.134     6     7
# 28     2018.12.18   788  kken****    211.36.***.87     0     0
# 29     2018.12.18   859  jae5****  117.111.***.195     1     1
# ...           ...   ...       ...              ...   ...   ...
# 40787  2017.06.07   645  yuha****   124.63.***.201     2     2
# 40788  2017.06.07   614  ddiy****  112.221.***.214     3     0
# 40789  2017.06.07   613  ddiy****  112.221.***.214     2     0
# 40790  2017.06.07   670  hear****    223.62.***.83     2     3
# 40791  2017.06.07   628  hook****      39.7.***.24     2     0
# 40792  2017.06.07   682  liza****    115.139.***.5     3     0
# 40793  2017.06.07   594  k791****    223.39.***.13     4     0
# 40794  2017.06.07   590  song****   211.36.***.171     1     0
# 40795  2017.06.07   618  qkdc****    223.62.***.11     0     3
# 40796  2017.06.07   645  ddiy****  112.221.***.214     7     2
# 40797  2017.06.07   568  daco****   211.212.***.61     1     0
# 40798  2017.06.07   594  doc7****     223.39.***.9     1     0
# 40799  2017.06.07   604  ktbk****    223.62.***.56     5     0
# 40800  2017.06.07   672  yout****   210.106.***.20     2     0
# 40801  2017.06.07   651  chog****    61.83.***.187     4     0
# 40802  2017.06.07   736  jame****  175.223.***.168     1     6
# 40803  2017.06.07   773  bumk****   223.62.***.238     4     5
# 40804  2017.06.07   685  king****    223.62.***.56     6     0
# 40805  2017.06.07   790  mata****   223.62.***.188     2     3
# 40806  2017.06.07   755  tapo****    223.62.***.18     6     3
# 40807  2017.06.07   780  dhrm****   223.62.***.141     5     1
# 40808  2017.06.07   869  trus****    49.175.***.45     3    11
# 40809  2017.06.07   831  nanu****   125.185.***.21     2     3
# 40810  2017.06.07   875  nice****    1.224.***.165     1     5
# 40811  2017.06.07   813  syle****   211.36.***.144     2     1
# 40812  2017.06.07   785  hook****      39.7.***.24     4     4
# 40813  2017.06.07   787  hook****      39.7.***.24     2     2
# 40814  2017.06.07   873  hjle****   112.154.***.84    35     5
# 40815  2017.06.07   615  yuha****   124.63.***.201     1     0
# 40816  2017.06.07  1040  suga****    180.65.***.37     1     5
#
#                                                     text  \
# 0                                              0.28퍼 상승중
# 1                                                     폭락
# 2      문빠들이 쓴소리하는 어르신들을 틀딱이라 욕하지만 요즘 20대가 반문재인 세력으로 돌...
# 3      Today is...\r\nThe gap-Sang continues until th...
# 4                                             내일도 불기둥 가자
# 5      1년만 더기다리기로 결정함 내년 연말 배당타야죠. 20년 5조 영업이익 예상\r\n...
# 6                                              감사나 받아라..
# 7                한전 16연패 끊고\r\n\r\n드디어 시즌 첫승\r\n\r\n대호재다
# 8                       www.okatom.org 지금 바로 서명동참 가능합니다.
# 9      요즘 대학가 대자보에 재앙이 왕시리즈가 유행이라던데...\r\n\r\n과거 최불암 ...
# 10                                   현재 49.29\r\n3프로대 하락
# 11                                       ㅋㅋㅋ 그때가 매도시점이다.
# 12          문정부.\r\n\r\n탈원전이란.용어사용안하겠다!.\r\n\r\n원전.풀가동~~
# 13     현재 기름 먹는 자동차가 전기 먹는 자동차로\r\n10년~20년내 전부 바뀝니다 한...
# 14     한전이 6000~7000억을 들여 대학을 설립하고 매년 운영비가 600~700억 들...
# 15                        너무 많아서 정리가 안된다.\r\n\r\n재앙이다...
# 16                   지수 바닥이다\r\n내년 1850P 되면 한전 44000원 될듯
# 17      내일도 상승 예상 kps도 오늘 하락장에서도 기관이 매수하는걸 보면 한전관련주가 대세.
# 18                                              3자 가즈아~!
# 19     화요일인 금일밤 미국시장은 요동을 칠 것이다\r\n\r\nA-5파동이 진행되면서 전...
# 20                                 민간인 사찰은 거짓? 진실은 밝혀질까?
# 21     한전이 조금씩 원상복구되니까 왜 문딱들이 설쳐되노?\r\n\r\n\r\n문딱들은 이...
# 22                                매주 토요일 1시 서울역으로 모여주세요.
# 23     오늘도 개미는 기관과 외인에게 30만주를 줬다...삼성에서는 36만주를 팔았네 ㅠㅠ...
# 24     지지난주에 31층에 분양 받았는데\r\n\r\n연일 수익이네요\r\n\r\n40층 ...
# 25                                나에게 +3%를 먹여줬어.. 이젠 용서함
# 26                                     그것만큼 좋은 호재가 있나???
# 27     감을 잊엇나 본데\r\n\r\n아직 재앙이 쩡쩡하게 ~ 적와대에서 .. 문밥하믄서 ...
# 28     한전bps성장은정체\r\n하이닉스bps는급성장\r\neps와bps가같이커지는종목이\...
# 29            오늘도 개미만 이 좋은장에 털리는구만 개미 상승장 에 다 털림 특히 삼성증권
# ...                                                  ...
# 40787                                              개지랄떠네
# 40788  모두들 대피하시오 3시20분 조루공식 나오는 타임입니다. ㅋㅋㅋㅋ 이제부터 파랭이작...
# 40789                                     조루공식 오늘도 실천중..
# 40790                      매수물량 몇만개 박아놓고 딱 버티네\r\n다주워담는중
# 40791          종가 마이너스 이프로정도 예상했으나\r\n현주가상태유지한다면 단기상승가능함
# 40792                        전기차 에어컨 여름 무더위\r\n\r\n다 헛소리
# 40793  한전주 지금은 희망 없습니다\r\n석탄 원자력건설 중지\r\n태양광 , 풍력 비싸게...
# 40794  아 쉬밤~ 정보정보 정신이 없네~~ 알고 있는 분들은 정보주는 착한일 하시지 말규 ...
# 40795  엘디플하고 이넘하고 보다 이넘매수 했는데 내가 잘못했네 미안허네ㅋㅋ 그런데 계좌는 ...
# 40796  조루공식정리!! 참고바람요~^^\r\n1. 아침에 빨갱이 만들어서 개미들 현혹한다....
# 40797                                              ㅋㅋㅋㅋㅋ
# 40798                                            공매도치나보네
# 40799                                              ㅅㅂ개잡주
# 40800                                                카악퉤
# 40801                                  지랄도 풍년이다 개잡주에 개사장
# 40802  올리고\r\n담주 월요일부터 내릴 생각이군..\r\n항상 리듬이 비슷하네..\r\n...
# 40803                                        ㅋㅋㅋ그런게 있을리가
# 40804                                               아개잡주
# 40805     저평가 기준\r\n저 PER 저 PBR\r\n\r\n분할로 사두고 1년 묶혀봐...
# 40806                        해당종목을 잘 골랐다는 것의 반증이다\r\n가져가
# 40807  작작해 광고들아 번호써서\r\n가난하고 순진한 개미들 등골\r\n쭉쭉빼먹으니 좋냐?...
# 40808  4월 말쯤 대충 아무거나 대형주 샀는데..\r\n\r\n오늘도 급등중 수익 21% ...
# 40809           태양광, 풍력, 가스 기타 등등 결국에는 한국전력 통해서 전기 판매한다.
# 40810  대차잔고가 350만주 정도로 줄어들어 있었는데\r\n어제 하루에만 140만주 이상의...
# 40811                                                  .
# 40812                                                 진리
# 40813                                                 대박
# 40814  모르고서 마구잡이 대책으로 국가 에너지산업기반을 무너뜨리고 있다.\r\n봄철 우리나...
# 40815                                        국민을 개똥으로 알지
# 40816  KBS 뉴스\r\n기로에 선 원전…신고리 5·6호기 운명은? 본문듣기 설정\r\n기...
#
#                                                    reply
# 0                                                    NaN
# 1                                                     []
# 2      ['아가 다좋은데 뛰어쓰기 좀하자.\n틀딱들 눈 다버리겠다.\n아무리 틀딱이 바보멍...
# 3                                                     []
# 4                                                     []
# 5                      ['아이디어 굿!\n감사합니다\n문 탄핵하면 한전에 투자']
# 6      ['문재앙이 공매도들 처리나 좀 하징,,,,,하는 일도 없는데,,,,,,아니,,,,...
# 7                                                     []
# 8                                                     []
# 9                                                     []
# 10     ['유가 150달러 일때 어떻게 버텼는지 몰러요', '국제유가 하락 속도를 한전이 ...
# 11                                         ['시끄럽다 알아서해']
# 12                                                    []
# 13     ['사필귀정 전기차시대에는 한전이 대장주', '밧데리 한대 값이 2000만원 이면 ...
# 14     ['지껄여댈때마다 도대체 뇌가 있는건지 의심스럽다못해 숨이 턱턱 막히는군.', '특...
# 15     ['우리 민족끼리 더불어 민노당 사회주의 이념으로 위험하고 자유 시장경제에 대해 무...
# 16                         ['45000몰팡자입니다 1000만더 인싱 쓰세요']
# 17     ['지금은 쉬든지 방어주를 사든지 선택지밖에 없어서 그럽니다. 방어주들 중에서도 탑...
# 18                                                    []
# 19     ['미국시장과 한전은 크게 영향을 안받습니다.', '또라이냐', '그래서 지수 18...
# 20     ['흔적 지우고 그런 말 지어내지 한걸레 기자 출신 청와대 대변인 가짜뉴스 공장',...
# 21     ['6만원에 안처물렷는데 밑에 문딱아 ㅋㅋㅋ', '6만원에 쳐물린 틀딱들ㅋㅋㅋㅋ',...
# 22                                                    []
# 23                                                    []
# 24                                  ['엘베를 타면 근방 갈듯....']
# 25     ['참..찌질하다....나라 말아 쳐먹는 매국노 같은 넘을..', '45000몰방자...
# 26                                                    []
# 27     ['따라다니면서 반대 누질르는.. 달창 ㅅ ㅋ 가 한마리 잇네 ㅋㅋㅋㅋ... 그래 ...
# 28                                        ['누가 풀어서 설명좀']
# 29     ['ㅋㅋ', '요번에는 삼성공화국 과 대한민국 경제 전쟁에서 대한민국이 이긴다고 판...
# ...                                                  ...
# 40787                                                 []
# 40788                                                 []
# 40789                                                 []
# 40790                                    ['내보기엔 먹튀같은디?']
# 40791                                                 []
# 40792                             ['이미 다 반영된 가격이 43000']
# 40793                                                 []
# 40794  ['전부 개미들꼬셔서 투자하게하고\n사기비슷함 추천종목도 주로 고점매수 하라고 지랄...
# 40795                                                 []
# 40796                                         ['오~고수 ㅎ']
# 40797                                                 []
# 40798                                                 []
# 40799                         ['얘는 원래가 코스피 오르면 빌빌댑니다요~']
# 40800                                                 []
# 40801                                                 []
# 40802                                                 []
# 40803                                                 []
# 40804                                                 []
# 40805                                                 []
# 40806  ['물린 호구들이 많아서 게시판 들락날락 거리는게 활성화 되었다는 얘기지.\n종목을...
# 40807  ['댓글동시다발적 아이디다르게아이피다르게 올라오는거보면 딱봐도 본인이글쓰고 댓글다는...
# 40808  ['이야 비공수 보소 ㅋㅋ 배아픈분들 많네..\n\n종목 까고 싶지만, 개미 올라타...
# 40809                                                 []
# 40810                                      ['뭐긴.. 망한거지']
# 40811                                                 []
# 40812                                      ['개잡주라면그럴수도']
# 40813                                                 []
# 40814  ['노예가 어찌 주인에게. 이래라 저래라 하겠소. ㅋㅋ\n노예디엔에이.', '진짜 ...
# 40815                                                 []
# 40816  ['일부러 그 기사에 공사중단과 6월말까지로 기한이 나온 것처럼 글을 쓰는 이유가 ...
#
# [40817 rows x 8 columns]

# %%
hinix.drop('mola',axis=1, inplace=True)
hinix.drop('like',axis=1, inplace=True)
hinix.drop('hate',axis=1, inplace=True)
hinix.drop('id',axis=1, inplace=True)
hinix.drop('ip',axis=1, inplace=True)
hinix.drop('reply',axis=1, inplace=True)
#hinix.drop('index',axis=1, inplace=True)

# %%
#############str 아닌거 확인 
idx=0
idx_list=[]
string_type = 'k'
for aaaa in hinix['text']:
    if type(aaaa)!=type(string_type):
        print(idx,type(aaaa))
        idx_list.append(idx)
    idx+=1

# %%
for idx in idx_list:
    hinix['text'].iloc[idx]=str(hinix['text'].iloc[idx])

# %%
#############결과 확인 
idx=0
idx_list=[]
st = 'k'
for aaaa in hinix['text']:
    if type(aaaa)!=type(st):
        print(idx,type(aaaa))
        idx_list.append(idx)
    idx+=1

# %%
hinix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40817 entries, 0 to 40816
# Data columns (total 2 columns):
# date    40817 non-null object
# text    40817 non-null object
# dtypes: object(2)
# memory usage: 637.8+ KB

# %%
# ## 문장들을 꺼내서 오브젝트에서 str 타입으로 바꾸는 작업
# def str_token_join(data):
#     hinix_text_str = ' '
#     hinix_str = []
#     result = []
#     for text_list in data:        
#         for text in text_list:
#             # 객체 -> 문자열
#             str_text = str(text)
#             #태그 선별하기 
#             dict_tags = {'NNG':1,'NNP':1,'NNB':1,'VV':1,'VA':1,'VCP':1,'VCN':1,'MM':1,'MAG':1,'IC':1,'JX':1,'SF':1,'SE':1,'SL':1, 'SW':1, 'SN':1,'XPN':1}
#             #현쨰 글자의 태그가 목록에 있는지 없는지 확인 
#             tag = str_text[str_text.find('/')+1:]
#             tag_split = str_text[str_text.find('/')+1:].split(' ')[0]
#             tmp = dict_tags.get(tag_split)
#             print(tag,tag_split)
#             if tmp !=None:
#                 hinix_str.append(str_text[str_text.find('\t')+1:].replace(' + ',' '))              
#         result.append(hinix_text_str.join(hinix_str))    
#         hinix_str=[]
#     return result

# %%
# idx = 0 
# for text_list in hinix['text']:    
#     if idx == 2:
#         break
#     print(text_list)
#     idx +=1

# %%
## 문장들을 꺼내서 오브젝트에서 str 타입으로 바꾸는 작업
def str_token_join(data):
    hinix_text_str = ' '
    hinix_str = []
    result = []
    for idx, text_list in enumerate(data):        
        for text in text_list:
            #마디를 문자열로 변경 
            str_text = str(text)
            # +가 있는 마디가 있을수 있기 split으로 list를 담아줌  
            corpus = str_text[str_text.find('\t')+1:].split(' + ') # 자른걸 원소로 가지도록             
            dict_tags = {'NNG':1,'NNP':1,'NNB':1,'VV':1,'VA':1,'VCP':1,'VCN':1,'MM':1,'MAG':1,'IC':1,'JX':1,'SF':1,'SE':1, 'SW':1, 'SN':1,'XPN':1}
            
            # 각 list가 원하는 태그인가 아닌가 검증            
            for corpus_element in corpus:
                #corpus_element => 형태소 하나하나.
                tag = corpus_element[corpus_element.find('/')+1:]                    
                tmp = dict_tags.get(tag)                
                if tmp !=None:  
                    #,;{}()\n\t=
                    if corpus_element.find(')')>=0 or corpus_element.find('(')>=0 or corpus_element.find(';')>=0 or corpus_element.find(',')>=0 or corpus_element.find('{')>=0 or corpus_element.find('}')>=0 or corpus_element.find('=')>=0:
                        pass
                    else:
                    # 이 text를 text_list가 되도록 리스트에 담는다.
                        hinix_str.append(corpus_element)               
        # 리스트가 아닌 str을 담아주기 위해 join을 이용한다.
        #print(hinix_str)
        result.append(hinix_text_str.join(hinix_str))
        #hinix_str 초기화 
        hinix_str=[]         
    return result

# %%
### dict_tags = {'NNG':1,'NNP':1,'VV':1,'VA':1,'VCP':1,'VCN':1, 'MAG':1}
# print(dict_tags.get('a'))

# %%
# g = '그래서/MAJ'
# g[g.find('/')+1:]

# %%
# kkk = 'MAG babo'
# print(kkk.split(' , '))
# print(kkk.split(' '))
# a = ['list','babo']

# %%
start_time=time.time()
hinix_text = hinix['text']#원하는 프로그램 => 1000개씩 잘라서 tokenizer 한다음에 저장한다.
stride = 5000
# 코드 제대로 설계를 못하고 짬.
for _ in tqdm_notebook(range(len(hinix_text)//stride+1)):        
    # 1000개로 쪼개기
    
    hinix_tmp = hinix_text[:min(stride,len(hinix_text))] #1000개 이하개 일수도 있으므로    
    #tokenizer 하기
    hinix_text_token = hinix_tmp.apply(lambda x:api.analyze(x)) # 1000개 단위로 자른거 형태소 분석 
    hinix_text_token = pd.DataFrame(str_token_join(hinix_text_token))
    #저장하기
    with open('../token/naver_{0}_token.csv'.format(stock_code),'a',encoding='utf-8') as f:
        hinix_text_token.to_csv(f, header=False, index= False,encoding='utf-8')
    if len(hinix_text) < stride:
        break    
    hinix_text = hinix_text[stride:]    
print('걸린시간:',time.time()-start_time)
# Out:
# HBox(children=(IntProgress(value=0, max=9), HTML(value='')))

# %%
#1000개 단위 걸린 시간 : 
#5000개 단위 걸린 시간:

# %%
hinix_token = pd.read_csv('../token/naver_{0}_token.csv'.format(stock_code),encoding='utf-8',header=None)

# %%
print(hinix_token.shape, type(hinix_token))
print(len(hinix_token.iloc[0,:]))
hinix_token.head(100)

# %%
# ddd= 'a '
# print(ddd,'b')
# print(ddd.strip(),'b')

# %%
hinix_repl = hinix[:]

# %%
hinix_repl['text'] = hinix_token

# %%
hinix_repl.head(10)

# %%
#cf = pd.read_csv('./naver_000660_token_full.csv',encoding='utf-8',header=None)

# %%
sum(hinix_repl['text'].isnull())

# %%
hinix_repl.dropna(inplace=True)

# %%
sum(hinix_repl['text'].isnull())

# %%
print(hinix.shape,hinix_repl.shape)

# %%
with open('../kai_result/naver_{0}_kai.parquet'.format(stock_code),'wb') as f:
    hinix_repl.to_parquet(f)

# %%
# hinix_sample = hinix_repl[:10000]
# with open('./naver_{0}_sample.csv'.format(stock_code),'w',encoding='utf-8') as f:
#     hinix_sample.to_csv(f, index= False,encoding='utf-8')

# %%
# hinix_sample500 = hinix_repl[:500]
# with open('./naver_{0}_sample500.csv'.format(stock_code),'w',encoding='utf-8') as f:
#     hinix_sample.to_csv(f, index= False,encoding='utf-8')

# %%
# def asl(ttt):
#     for word in ttt.split(" "):
#         if word.find('A/SL')>=0:
#             print(word)

# %%
# num = 0
# for idx in range(len(hinix_token)):
#     tmp = str(hinix_token.iloc[idx,0])
#     pos =tmp.find('.')    
#     if pos>=0:        
#         print(tmp)
#         num+=1
#     if num == 20:
#         print(idx)
#         break

# %%
# for ttt in hinix_token:
#     if ttt.find('.')>=0:
#         print(ttt)
# #     for word in ttt.split(" "):
# #         if word.find('A/SL')>=0:
# #             print(word)

# %%
# stime=time.time()
# hinix_repl['text'].apply(lambda x:asl(x))

# print(time.time()-stime)

# %%
#  with open('./naver_{0}_kai.csv'.format(stock_code),'w',encoding='utf-8') as f:
#     hinix_repl.to_csv(f, index= False,encoding='utf-8')

# %%
#ori = pd.read_csv('./naver_{0}_kai.csv'.format(stock_code),encoding='utf-8')
