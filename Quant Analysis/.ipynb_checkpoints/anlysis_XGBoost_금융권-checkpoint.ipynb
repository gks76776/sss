# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale

# %%
kospi_200_items = pd.read_excel('./data/1222dataset.xlsx')

# %%
kospi_200_items.columns
# Out:
# Index(['Name', 'PER(배)', 'PSR(배)', 'PBR(배)', '외국인보유비중(티커)(%)', '변동성 (20일)',
#        '거래량 (20일 평균)(주)', '공매도거래량 (20일)(주)', '순매수수량(기관계)(20일합산)(주)',
#        '순매수수량(개인)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)', '수익률 (1개월)(%)',
#        '수익률 (3개월)(%)'],
#       dtype='object')

# %%
data
# Out:
#          PER(배)    PSR(배)    PBR(배)  외국인보유비중(티커)(%)  변동성 (20일)  \
# 0      1.035225 -0.133972 -0.159721        0.011540   1.292501
# 1     -0.030259  0.115959 -0.076024       -0.061662   0.847446
# 2      0.472109  0.172240  0.014702        0.054522  -0.662564
# 3     -0.367164 -0.086794  0.123678        0.133800  -0.360562
# 4      0.056293 -0.128642 -0.118006       -0.081524  -0.694353
# 5      0.145490  0.278479 -0.004906        0.027693  -0.646669
# 6     -0.208748  0.138299  0.145522       -0.005893  -0.233403
# 7      0.246867 -0.173372 -0.084687       -0.125007  -0.106244
# 8      0.193823 -0.185026 -0.193371        0.129018  -1.202988
# 9     -0.426732  0.154095 -0.011438        0.172852   0.195757
# 10    -0.200932 -0.145581 -0.132801       -0.010345   0.307021
# 11     0.287065 -0.063278  0.085277        0.065976   0.132178
# 12    -0.174404  0.021963 -0.011275        0.024954   0.036809
# 13    -0.240113 -0.087093 -0.103691        0.021699   0.322916
# ...

# %%
def data_sp(data):
    com_name_set = list(set(data.Name))
    
    ## 18년도 3,6월 이전 이후로 나누기
    train_set = pd.DataFrame()
    test_set = pd.DataFrame()
    for i in range(len(com_name_set)):
        sub_set = data[ data.Name == com_name_set[i]]
        train_set = train_set.append(sub_set[:-2])
        test_set = test_set.append(sub_set[-2:])
    return train_set , test_set

# %%
train,test = data_sp(kospi_200_items)

# %%
print(train.shape , test.shape)
# Out:
# (3153, 13) (382, 13)

# %%
train = train[['PER(배)', 'PSR(배)', 'PBR(배)', '외국인보유비중(티커)(%)', '변동성 (20일)',
       '거래량 (20일 평균)(주)', '공매도거래량 (20일)(주)', '순매수수량(기관계)(20일합산)(주)',
       '순매수수량(개인)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)','수익률 (3개월)(%)']]

test = test[['PER(배)', 'PSR(배)', 'PBR(배)', '외국인보유비중(티커)(%)', '변동성 (20일)',
       '거래량 (20일 평균)(주)', '공매도거래량 (20일)(주)', '순매수수량(기관계)(20일합산)(주)',
       '순매수수량(개인)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)','수익률 (3개월)(%)']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-c6e30e09d959> in <module>()
# ----> 1 data_sp(data)
#
# <ipython-input-13-1be03677213a> in data_sp(data)
#       1 def data_sp(data):
# ----> 2     com_name_set = list(set(data.Name))
#       3
#       4     ## 18년도 3,6월 이전 이후로 나누기
#       5     train_set = pd.DataFrame()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Name'

# %%
## 시각화
import seaborn as sns
# 한글 처리 시각화
import matplotlib.pyplot as plt
# 주피터 내장
# %matplotlib inline
# 한글처리 
import platform
from matplotlib import font_manager, rc

# 한글처리
plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':    # 맥
    rc( 'font', family='AppleGothic' )
elif platform.system() == 'Windows': # 윈도우
    # 폰트 차후 확인
    fontPath = 'c:/Windows/Fonts/malgun.ttf'
    fontName = font_manager.FontProperties( fname=fontPath ).get_name()
    rc( 'font', family=fontName )
else:
    print('알수없는 시스템. 미적용')

# %%
plt.figure(figsize=(40,30))
g = sns.heatmap(use_data.corr(),annot=True, fmt = ".2f", cmap = "coolwarm")

# %%
from numpy import loadtxt
from xgboost import  XGBRegressor
from xgboost import plot_importance

x = use_data[col_name1]
# x = use_data.drop(['수익률 (3개월)(%)'],axis=1)
y = use_data['수익률 (1개월)(%)']



model = XGBRegressor()
model.fit(x,y)
plt.figure(figsize=(100,100))
plot_importance(model)
plt.show()

# %%
col_name4 = ['급여(천원)', '매출액증가율(전년동기)(%)', '매출액증가율(전분기)(%)', '매출총이익증가율(전년동기)(%)',
       '매출총이익증가율(전분기)(%)', '영업이익증가율(전년동기)(%)', '영업이익증가율(전분기)(%)',
       '당기순이익증가율(전년동기)(%)', '당기순이익증가율(전분기)(%)', '총포괄이익증가율(전년동기)(%)',
       '총포괄이익증가율(전분기)(%)', 'EBITDA증가율(전년동기)(%)', 'EBITDA증가율(전분기)(%)',
       '총자산증가율(전년동기)(%)', '총자산증가율(전분기)(%)', '총부채증가율(전년동기)(%)',
       '총부채증가율(전분기)(%)', '총자본증가율(전년동기)(%)', '총자본증가율(전분기)(%)',
       'EPS증가율(전년동기)(%)', 'EPS증가율(전분기)(%)', 'BPS증가율(전년동기)(%)',
       'BPS증가율(전분기)(%)', 'ROA(총포괄이익)(%)', 'ROE(당기순이익)(%)', '총자산회전율(회)',
       '총부채회전율(회)', '총자본회전율(회)', '변동성 (20일)', '거래량 (20일 평균)(주)',
       '외국인보유비중(티커)(%)', '공매도거래량 (20일)(주)', '순매수수량(기관계)(20일합산)(주)',
       '순매수수량(개인)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)', '순매수수량(기관/외국인계)(주)',
       'PER(배)', 'PSR(배)', 'PBR(배)']
len(col_name3)

# %%
use_data.columns

# %%
col_name3 = ['매출총이익증가율(전년동기)(%)','총자산증가율(전분기)(%)','변동성 (20일)', '거래량 (20일 평균)(주)',
       '외국인보유비중(티커)(%)','순매수수량(기관계)(20일합산)(주)', 'PSR(배)', 'PBR(배)']
print(len(col_name3))
x = use_data[col_name4]
# x = use_data.drop(['수익률 (3개월)(%)'],axis=1)
y = use_data['수익률 (3개월)(%)']



model = XGBRegressor(n_estimators=500,)
model.fit(x,y)
plt.figure(figsize=(100,100))
plot_importance(model)
plt.show()
