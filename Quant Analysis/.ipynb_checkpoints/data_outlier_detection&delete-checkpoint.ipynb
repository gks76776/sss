# %%
import pandas as pd
import numpy as np
import sklearn.

# %%
raw_Data = pd.read_csv('./data/aa44.csv')

# %%
raw_Data
# Out:
#       매출액증가율(전년동기)(%)  매출액증가율(전분기)(%)  매출총이익증가율(전년동기)(%)  매출총이익증가율(전분기)(%)  \
# 0                7.63           11.66             -21.09             13.38
# 1               18.25           -1.46               3.47              1.78
# 2                7.04            4.48             -40.62            -11.07
# 3                5.20           -3.44              41.04            326.26
# 4               30.75           22.48             176.00             99.17
# 5                8.34          -13.43              94.80            -37.23
# 6               10.14            1.21              30.80             -6.71
# 7               -2.52            8.41             -15.73             28.32
# 8               12.96            0.32              20.94             -9.91
# 9               27.74            4.92              54.34             15.30
# 10              26.78            9.69              23.37             17.72
# ...

# %%
sklear
