# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
# data_fin = pd.read_excel('./kospi200_공시기간_조정_전체_데이터.xlsx',sheet_name='fin')
# data_revenue = pd.read_excel('./kospi200_공시기간_조정_전체_데이터.xlsx',sheet_name='수익률_행열변환')
# data_tech = pd.read_excel('./kospi200_공시기간_조정_전체_데이터.xlsx',sheet_name='tech_행열변환')

# %%
data_fin = pd.read_excel('./new_data (1).xlsx',sheet_name='재무데이터')
data_revenue = pd.read_excel('./new_data (1).xlsx',sheet_name='3개월 수익률')
data_tech = pd.read_excel('./new_data (1).xlsx',sheet_name='기술데이터')
data_stop = pd.read_excel('./new_data (1).xlsx',sheet_name='3개월 거래정지')

# %%
def revenue_Data_reshape(data_revenue):   ## 11월 수익률은 6월 데이터가 없기 떄문에 쓸 수 없다.
    com_name = list(data_revenue.iloc[0][5:])
    #     col_name = '수익률 (3개월)(%)'
    index_list = data_revenue['Item'][1:]

    values = data_revenue.iloc[1:,5:]
    values.columns = com_name

    ## 11월 수익률은 6월 데이터가 없기 떄문에 쓸 수 없다.
    b = values
    b.index = index_list

    b.loc[20140515.0] = np.nan
    b.loc[20150515.0] = np.nan
    b.loc[20160515.0] = np.nan
    b.loc[20170515.0] = np.nan
    b.loc[20180515.0] = np.nan

    ind = list(b.index)
    ind.sort()
    
    return b.loc[ind].iloc[1:]

# %%
# 2013년 9월 ~ 2018 년 6월 완료
revenue = revenue_Data_reshape(data_revenue)
revenue
# Out:
#              삼성전자 SK하이닉스    현대차   LG화학  SK텔레콤  POSCO  현대모비스     SK LG생활건강 SK이노베이션  ...    한국쉘석유    SBS S&T모티브   한국단자  현대리바트     무학    유니드  한일홀딩스    팜스코  한진중공업
# Item                                                                               ...
# 20140215.0  -8.64   20.9  -4.32  -7.25 -11.21  -9.24   8.73  11.25   -9.4   -1.85  ...   -13.16  -9.12   3.48  -0.83  46.63  13.49   4.82  21.56  53.15  24.22
# 20140515.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 20140815.0 -10.88   3.44  -3.16   5.22  16.74   6.05  -2.32  27.94   5.05   -9.78  ...    19.78   -4.7  24.61   2.95  26.11   9.93  -1.79  10.55   4.06  -38.9
# 20141115.0  -5.31  12.97 -23.04 -25.55   6.98 -11.56 -19.52   7.69  15.69  -15.27  ...   -19.31 -14.47  16.81  31.57   -2.3  -4.82 -10.77  -6.71   6.74 -32.65
# 20150215.0  13.42  -2.18 -11.48   7.86   7.65 -11.24   1.69  -1.08  15.16   14.73  ...     5.46  27.41   4.82   6.48  17.63  23.61   2.38  24.16  -6.17 -14.19
# 20150515.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 20150815.0 -14.48 -18.45 -12.95 -18.74  -1.19 -27.03 -12.77   24.2  -3.06  -17.93  ...    -6.85 -27.94   2.95  44.81  71.68  25.89  18.54 -16.44  38.93 -28.91
# 20151115.0  14.04 -15.58    8.3  32.82  -7.01  -9.52  20.73 -23.03   8.99   15.27  ...    12.82  18.52   5.87 -13.03 -45.22 -13.16 -18.54 -13.52 -25.19  -4.78
# 20160215.0 -11.23 -11.08 -10.86  -6.18  -6.68  10.23    0.2  -8.58  -3.79   14.04  ...    -7.21 -12.72   6.97   12.7   3.43 -35.81 -13.89  -7.58  -2.75 -18.22
# 20160515.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 20160815.0  20.61  31.61  -0.37  -7.99   6.09   5.49   0.58   6.09  -5.26    -1.3  ...    -2.25 -10.77 -11.96  -6.02  -8.35 -22.34  -6.59 -22.73   8.79  21.51
# 20161115.0  -0.39  15.57  -4.04  -9.25  -3.97  14.93  -6.73   4.19 -15.96    5.92  ...    -1.87  -1.53 -34.82 -10.63  -8.04   -0.6   5.64  -7.18 -19.19  -10.6
# 20170215.0  22.55  20.65  11.49  17.26   3.45  11.02   3.51  -4.03   1.44   -2.48  ...    -5.26   1.56  20.46  -0.81  13.01  -6.07  -9.75   1.77   1.25 -26.77
# 20170515.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 20170815.0  -1.79  17.72  -6.77  19.48  14.19  19.27   2.23   8.38   1.15    0.58  ...    -0.25    8.2  10.37  -4.43 -16.73  -5.82   5.16     -4  -1.57  16.58
# 20171115.0  22.98  25.96  11.76  15.57  -6.49  -5.38   5.54   8.66   25.7   12.64  ...    -1.36 -12.27  -9.39      0   16.7 -17.16  -8.11  17.08   -3.2  -14.8
# 20180215.0 -12.37  -6.95  -3.74   -5.1  -2.79  13.95 -16.23    1.4 -12.07   -6.16  ...    -7.78  -0.82  -6.44  -6.32   -2.8   6.22  -3.17 -10.76   1.65  -7.87
# 20180515.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     NaN  ...      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 20180815.0  -9.88 -11.12 -18.54   5.22  17.42 -13.21  -4.17 -14.38  -8.14   -2.93  ...     3.44 -28.68  -0.58  -8.51   2.35  -12.5  -8.57 -27.32 -14.67 -25.56
# 20181115.0  -1.99   -5.4 -16.26  -8.31   2.89 -21.43 -16.74   5.98  -1.86   -1.51  ...     0.87   11.9 -26.53 -22.19 -21.92 -21.43 -25.78 -27.22 -20.45 -31.69
#
# [20 rows x 149 columns]

# %%
# 회사별로 reshape  20
def reshape_fin_dataset(data):
    ##  쓸데없는 칼럼 제거
    company_name = list((data.iloc[8]))
    col_name = list(data.iloc[11])
    data = data.iloc[13:]
    data.columns = col_name
    col_num = len(list(set(col_name)))
    
    # 더미 데이터셋 생성
    sets = pd.DataFrame()    
    for i in range(len(set(company_name))):
        ## 회사 별로 뽑아오기
        sub_dataset = data.iloc[:,i*col_num : (i+1)*col_num][:-3]
        sub_dataset['Name'] = company_name[i*col_num]
        sets = sets.append(sub_dataset)
        
    return sets

# %%
# 2013년 9월 ~ 2018 년 6월 완료
fin = reshape_fin_dataset(data_fin)
fin
# Out:
#            부채비율(%) 총자산/총자본(%) 매출액증가율(전년동기)(%) 매출총이익증가율(전년동기)(%) 영업이익증가율(전년동기)(%) 당기순이익증가율(전년동기)(%) 총포괄이익증가율(전년동기)(%) EBITDA증가율(전년동기)(%) 총자산증가율(전년동기)(%) 총부채증가율(전년동기)(%)   ...   ROE(당기순이익)(%) 총자산회전율(회) 총부채회전율(회) 총자본회전율(회) 현금및현금성자산구성비율(%) 차입부채/EBITDA(배)   EBITDA(천원)  CFPS(원) P/EBITDAPS(배)    Name
def reshape_tech_dataset(data_tech):
    col_name = list(data_tech.Symbol[1:])  # set 노노
    com_name = list(data_tech.iloc[0,5:]) ## set 완료
    values = data_tech.iloc[1:,5:]
    values.columns = com_name
    index = list(set(data_tech['Item']))[1:]
    index.sort()

    full_dataset = pd.DataFrame()

    for i in com_name:
        sub_dataset = values[i]
        a = np.array(sub_dataset)
        sub_dataset = pd.DataFrame(a.reshape(-1,int(len(a)/len(set(col_name))))).T
        sub_dataset['Name'] = i
        sub_dataset.index = index
        sub_dataset = sub_dataset.iloc[:-1].loc[[20130815.0, 20131115.0, 20140215.0, 20140515.0, 20140815.0, 20141115.0, 
                                                 20150215.0, 20150515.0, 20150815.0, 20151115.0, 20160215.0, 20160515.0,
                                                 20160815.0, 20161115.0, 20170215.0, 20170515.0, 20170815.0, 20171115.0, 
                                                 20180215.0, 20180515.0, 20180815.0]]

        full_dataset = full_dataset.append(sub_dataset)

    col = ['변동성 (20일)','거래량 (20일 평균)(주)','외국인보유비중(보통+우선)(%)','공매도거래량 (20일)(주)','순매수수량(개인)(20일합산)(주)',
           '순매수수량(기관계)(20일합산)(주)','순매수수량(외국인계)(20일합산)(주)','PER(IFRS-연결)','PBR(IFRS-연결)','PSR(IFRS-연결)',
           'Name']

    full_dataset.columns = col    
    return full_dataset

# %%
# 2013년 9월 ~ 2018 년 6월 완료 but 2013년 2분기 데이터도 존재 ( 변화율 생성 위함 )
tech = reshape_tech_dataset(data_tech)
tech
# Out:
#            변동성 (20일) 거래량 (20일 평균)(주) 외국인보유비중(보통+우선)(%) 공매도거래량 (20일)(주) 순매수수량(개인)(20일합산)(주) 순매수수량(기관계)(20일합산)(주) 순매수수량(외국인계)(20일합산)(주) PER(IFRS-연결) PBR(IFRS-연결) PSR(IFRS-연결)    Name
# 20130815.0    0.0166          251864           52.1532           82680              237168                41323               -280221         9.54         1.78          1.1    삼성전자
# 20131115.0     0.016          204583           54.2013           75364             -150564              -463258                625266        10.73            2         1.24    삼성전자
# 20140215.0    0.0123          233097           54.1539          148719               12502               -92046                 96793         7.42         1.46         0.97    삼성전자
# 20140515.0    0.0125          221661           54.8847          308753             -311712               116119                196707         8.04         1.58         1.05    삼성전자
# 20140815.0    0.0168          251686           55.2201          211287              180065              -481917                298978         7.19         1.41         0.94    삼성전자
# 20141115.0     0.025          254635           56.3332          281502             -325963              -540394                878777         6.81         1.34         0.89    삼성전자
# 20150215.0    0.0123          210872           55.1914          189765             -270991               309699               -275635        10.03         1.36         1.12    삼성전자
# 20150515.0     0.015          236497           55.5334          182876              402865              -686437                277025         9.77         1.32         1.09    삼성전자
# 20150815.0    0.0178          244510           55.4743          382617              304956                 4957               -309096          8.4         1.14         0.94    삼성전자
# 20151115.0    0.0133          238093           54.3242          215475             -319235               106375               -265935         9.58          1.3         1.07    삼성전자
# 20160215.0      0.02          228692            53.458          352144               13993                10798               -322234         10.5         1.05         0.98    삼성전자
# 20160515.0    0.0126          193573           54.1345          255329              -94738              -349089                189236         11.4         1.14         1.06    삼성전자
# 20130815.0    0.0309          495240           8.00755          375492             -368838              -743773               1155101          NaN         0.35         0.23   한진중공업
# 20131115.0    0.0301          415548           8.35347          243830              273251              -463423                238688          NaN         0.33         0.22   한진중공업
# 20140215.0    0.0347          606130           9.77213          717840             -947756              1021543                 45113          NaN         0.55         0.34   한진중공업
# 20140515.0    0.0282          598429           6.94409         1847949             1610317               224466              -1709716          NaN         0.48          0.3   한진중공업
# 20140815.0    0.0159          649643           6.83563         2551219             1000161              -776021               -156389          NaN          0.3         0.18   한진중공업
# 20141115.0    0.0306         1078250            4.4065         2023622             2847561             -3350397                129549          NaN          0.2         0.12   한진중공업
# 20150215.0    0.0248          786179           2.94843         1060928             1249800             -1141186               -131517          NaN         0.26         0.13   한진중공업
# 20150515.0    0.0303         1084203           2.54377         1510440             1330439             -1541618                253599          NaN         0.36         0.18   한진중공업
# 20150815.0    0.0283          634701           2.23304          728794             1266456             -1669675                308179          NaN         0.27         0.14   한진중공업
# 20151115.0    0.0248          491477           2.52679          378775              296160              -571497                295209          NaN         0.26         0.13   한진중공업
# 20160215.0    0.0285          531658           4.06133          691818             -931725              -151707               1158408          NaN         0.28         0.11   한진중공업
# 20160515.0    0.0351          715044           5.64007          407794            -1015297               649642                292666          NaN         0.32         0.12   한진중공업
# 20160815.0    0.0209          543384           7.30833          194142            -1138460               121614               1062134          NaN          0.4         0.15   한진중공업
# 20161115.0    0.0238          267893           8.35877          190503             -739846               131633                609896          NaN         0.35         0.14   한진중공업
# 20170215.0    0.0203          447021           6.88106          543755             1140950               -70018              -1021668          NaN         0.35         0.11   한진중공업
# 20170515.0    0.0161          470740           4.01522         1480623              867766               793314              -1660728          NaN         0.43         0.14   한진중공업
# 20170815.0    0.0215          557367           4.30237          944892             -763411              1341112               -528384          NaN         0.51         0.16   한진중공업
# 20171115.0    0.0243          422803            4.0868          956555              341850              -373114                 80648          NaN         0.43         0.14   한진중공업
# 20180215.0    0.0261          466441           6.38652          457304             -908777              -221940               1151398          NaN          0.4         0.13   한진중공업
# 20180515.0    0.0201          363526           6.99165          944544             -623863               762884               -200214          NaN         0.66         0.15   한진중공업
# 20180815.0    0.0153          183344           6.62626          307244              303879              -599817                299062          NaN         0.48         0.11   한진중공업
#
# [3129 rows x 11 columns]

# %%
def stop_Data_reshape(data_stop):  
    com_name = list(data_stop.iloc[0][5:])
    
    index_list = data_stop['Item'][1:]

    values = data_stop.iloc[1:,5:]
    values.columns = com_name
    values.index = index_list
    
    return values.iloc[:-1]

# %%
# 2013년 9월 ~ 2018 년 6월 완료
stop = stop_Data_reshape(data_stop)
stop
# Out:
#            삼성전자 SK하이닉스 현대차 LG화학 SK텔레콤 POSCO 현대모비스  SK LG생활건강 SK이노베이션  ...  한국쉘석유 SBS S&T모티브 한국단자 현대리바트  무학 유니드 한일홀딩스 팜스코 한진중공업
# Item                                                                  ...
# 20131115.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20140215.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20140515.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20140815.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20141115.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20150215.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20150515.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20150815.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20151115.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20160215.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20160515.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20160815.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20161115.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20170215.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20170515.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20170815.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20171115.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20180215.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20180515.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
# 20180815.0   정상     정상  정상   정상    정상    정상    정상  정상     정상      정상  ...     정상  정상     정상   정상    정상  정상  정상    정상  정상    정상
#
# [20 rows x 149 columns]

# %%
def merge_data(fin, tech, revenue, stop):
    merged_dataset = pd.DataFrame()
    com_name = fin['Name']
    set_name = list(set(com_name))
    date_index = pd.DatetimeIndex(['2014-02-15', '2014-05-15', '2014-08-15', '2014-11-15',
                                     '2015-02-15', '2015-05-15', '2015-08-15', '2015-11-15',
                                     '2016-02-15', '2016-05-15', '2016-08-15', '2016-11-15',
                                     '2017-02-15', '2017-05-15', '2017-08-15', '2017-11-15',
                                     '2018-02-15', '2018-05-15', '2018-08-15', '2018-11-15'])
    
    for i in list((set_name)):
        # 회사 1개 불러오기
        fin_sub_set = fin[fin.Name == i]
        revenue_sub_set = revenue[i]
        ## 2016년 2분기 데이터도 포함됐기에 뺀다.
        tech_sub_set = tech[tech.Name == i].iloc[1:]
        tech_sub_set.drop(['Name'],axis=1,inplace=True)
        stop_sub_set = stop[i]
        
        revenue_sub_set = revenue_sub_set.rename('수익률 (3개월)(%)')
        stop_sub_set = stop_sub_set.rename('거래정지구분')
        
        fin_sub_set.index = date_index
        revenue_sub_set.index = date_index   
        tech_sub_set.index = date_index
        stop_sub_set.index = date_index

        ## tech & fin & revenue data 병합
        merged_Data = pd.concat([fin_sub_set, tech_sub_set, revenue_sub_set, stop_sub_set],axis=1)

        merged_dataset = merged_dataset.append(merged_Data)
        
    ## 중복되는 칼럼 삭제 요함
    merged_dataset = merged_dataset.loc[:,merged_dataset.columns.duplicated()==False]
    
    ## 내가 보기 편하게 칼럼 재조정
    merged_dataset = merged_dataset[['부채비율(%)', '매출액증가율(전년동기)(%)', '매출총이익증가율(전년동기)(%)',
       '영업이익증가율(전년동기)(%)', '당기순이익증가율(전년동기)(%)', '총포괄이익증가율(전년동기)(%)',
       'EBITDA증가율(전년동기)(%)', '총자산증가율(전년동기)(%)', '총부채증가율(전년동기)(%)',
       '총자본증가율(전년동기)(%)', 'EPS증가율(전년동기)(%)', 'BPS증가율(전년동기)(%)',
       'ROA(총포괄이익)(%)', 'ROE(당기순이익)(%)', '총자산회전율(회)','현금및현금성자산구성비율(%)', '차입부채/EBITDA(배)', 'EBITDA(천원)',
       'CFPS(원)','P/EBITDAPS(배)','변동성 (20일)', '거래량 (20일 평균)(주)', '외국인보유비중(보통+우선)(%)', '공매도거래량 (20일)(주)',
       '순매수수량(개인)(20일합산)(주)', '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)',
       'PER(IFRS-연결)', 'PBR(IFRS-연결)', 'PSR(IFRS-연결)','수익률 (3개월)(%)', 'Name','거래정지구분']]
    
    delete_com = ['현대그린푸드']
    
    for i in delete_com:
        merged_dataset = merged_dataset[merged_dataset.Name != i]
    
    # 수익률 칼럼 데이터 타입 변경
    merged_dataset['수익률 (3개월)(%)'] = merged_dataset['수익률 (3개월)(%)'].astype('float64')

    return merged_dataset

# %%
merged_Data = merge_data(fin, tech, revenue, stop)
merged_Data
# Out:
# 2015-08-15  128.51          -13.15             -13.7           -46.69            -76.46            -74.95             -26.46            1.53           -0.99            4.97  ...            170319              318851               -36974               -289808        15.33         1.61         0.71        -9.40   LS산전     정상
# 2015-11-15  122.56           -9.02             -0.21             -7.5            -38.11            -27.02               -3.3            1.11           -1.93             5.1  ...            183068             -162763               281016               -126306        14.07         1.48         0.66       -10.38   LS산전     정상
# 2016-02-15  118.84           -3.99              5.81             6.67            -48.42            -41.43               4.75             0.1           -1.75            2.38  ...            288786              -66723                73851                -18512        12.61         1.32         0.59       -15.92   LS산전     정상
# 2016-05-15  121.91            -3.9              1.88            -4.73             -32.9             -39.9              -1.94           -1.86           -4.91            2.14  ...            184042              557205              -294809               -266971        16.11         1.09         0.51          NaN   LS산전     정상
# 2016-08-15  124.77            3.21             16.13            86.57            242.58             233.9              39.24            2.65            1.32            4.36  ...            106596             -225648               305998                -70203        21.19         1.43         0.68       -10.20   LS산전     정상
# 2016-11-15  115.63           -1.06              7.17            12.08             14.89              2.42               7.04           -0.09           -2.71            3.12  ...            137789              159121                22011               -189364        19.16          1.3         0.61        -8.57   LS산전     정상
# 2017-02-15  114.33           -3.72             -3.94           -14.88             25.47             -0.98              -9.42            0.71           -1.07            2.83  ...            282927               88346                71818               -167547        17.52         1.19         0.56         6.21   LS산전     정상
# 2017-05-15  112.16            0.54             -4.85           -19.42             14.45             38.16              -12.5            0.45           -3.33            5.06  ...             50715             -377754               400403                -19369        16.21          1.2         0.59          NaN   LS산전     정상
# 2017-08-15  112.01           11.69              3.39             2.83             12.56             -23.5               0.49           -0.67           -5.46            5.31  ...            103928             -447785                59493                419420        20.07         1.49         0.73         9.31   LS산전     정상
# 2017-11-15  110.93           11.83              1.26            19.27             40.27             40.92              10.35            4.67            2.66            7.01  ...             21325             -307711               -90077                398691        21.82         1.62          0.8         2.73   LS산전     정상
# 2018-02-15   103.1           12.19              9.87            39.43             53.06             74.37              22.57            3.47           -1.53            9.19  ...             67479             -169295              -121602                293487        22.41         1.66         0.82       -10.49   LS산전     정상
# 2018-05-15   96.48            5.88              5.65            27.34             31.28             30.78              15.26           -0.26           -7.36             7.7  ...            122816              515044              -138879               -372692        20.29          1.5         0.74          NaN   LS산전     정상
# 2018-08-15  103.08            5.75             16.91            54.46             121.6            253.36              33.92            5.23             1.1            9.86  ...            280285             -303505               573968               -275553        22.84         2.05         1.02       -12.16   LS산전     정상
# 2018-11-15   96.77            9.09             18.69            51.65             58.16             73.44              33.07            2.51           -4.14            9.88  ...            101665              125238              -197764                 82458        20.21         1.81         0.91       -30.65   LS산전     정상
#
# [2960 rows x 33 columns]

# %%
merged_Data.to_excel('./merged_data.xlsx',encoding='utf-8')

# %%
merged_Data.columns
# Out:
# Index(['부채비율(%)', '매출액증가율(전년동기)(%)', '매출총이익증가율(전년동기)(%)', '영업이익증가율(전년동기)(%)',
#        '당기순이익증가율(전년동기)(%)', '총포괄이익증가율(전년동기)(%)', 'EBITDA증가율(전년동기)(%)',
#        '총자산증가율(전년동기)(%)', '총부채증가율(전년동기)(%)', '총자본증가율(전년동기)(%)',
#        'EPS증가율(전년동기)(%)', 'BPS증가율(전년동기)(%)', 'ROA(총포괄이익)(%)', 'ROE(당기순이익)(%)',
#        '총자산회전율(회)', '현금및현금성자산구성비율(%)', '차입부채/EBITDA(배)', 'EBITDA(천원)',
#        'CFPS(원)', 'P/EBITDAPS(배)', '변동성 (20일)', '거래량 (20일 평균)(주)',
#        '외국인보유비중(보통+우선)(%)', '공매도거래량 (20일)(주)', '순매수수량(개인)(20일합산)(주)',
#        '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)', 'PER(IFRS-연결)',
#        'PBR(IFRS-연결)', 'PSR(IFRS-연결)', '수익률 (3개월)(%)', 'Name', '거래정지구분'],
#       dtype='object')

# %%
def making_rate_of_change(sub_dataset,col):
    # 변화율 칼럼 삽입 / 기존 칼럼 삭제*********************************************************************
    for colname in col:
        # 변화율 백터 생성
        a = sub_dataset[colname]
        g = list(a.pct_change())

        ## 분보가 - 일때 방향성이 달라져서 -1 곱하기
        for i in list(range(len(a)))[:-1]:
            if list(a)[i] < 0:
                g[i+1] = g[i+1] * (-1)
                
            elif list(a)[i] == 0:
                g[i+1] = np.nan
                    
        sub_dataset[colname+'변화율'] = g
    
    sub_dataset = sub_dataset[1:]
        
    return sub_dataset

# %%
def scaling_data(sub_set):
    scaled_data = pd.DataFrame()

    sub_set = sub_set.iloc[1:]
    sub_set_y = sub_set.index
    
    scale_col = ['부채비율(%)','ROA(총포괄이익)(%)', 'ROE(당기순이익)(%)',
       '총자산회전율(회)', '현금및현금성자산구성비율(%)', '차입부채/EBITDA(배)', 'EBITDA(천원)',
       'CFPS(원)', 'P/EBITDAPS(배)', '변동성 (20일)', '거래량 (20일 평균)(주)',
       '외국인보유비중(보통+우선)(%)', '공매도거래량 (20일)(주)', '순매수수량(개인)(20일합산)(주)',
       '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)', 'PER(IFRS-연결)',
       'PBR(IFRS-연결)', 'PSR(IFRS-연결)']
    
    unscale_col = ['Name','수익률 (3개월)(%)', '3개월 수익률(4)', '3개월 수익률(2)']
    
    sub_set_x = sub_set[scale_col]
    sub_set_no = sub_set[unscale_col]
    
    ## 스케일 부분
    scaled_sub_set_x = pd.DataFrame(scale(sub_set_x),index = sub_set_y ,columns = scale_col)
    x = pd.concat([scaled_sub_set_x,sub_set_no],axis = 1)
    
    return x

# %%
def make_cate_t(data):
    ## 수익률 범주화
    bb = np.array([-100,0,100])

    Y_data_cat = np.digitize(data['수익률 (3개월)(%)'],bb)
    Y_data_cat = Y_data_cat - 1
    
    return Y_data_cat

# %%
def make_cate_f(data):
    ## 수익률 범주화
    bb = np.array([-100,-15,0,15,100])

    Y_data_cat = np.digitize(data['수익률 (3개월)(%)'],bb)
    Y_data_cat = Y_data_cat - 1
    
    return Y_data_cat

# %%
## 표춘편차 이용
def std_based_outlier(df):
    cols = ['부채비율(%)', '매출액증가율(전년동기)(%)', '매출총이익증가율(전년동기)(%)', '영업이익증가율(전년동기)(%)',
       '당기순이익증가율(전년동기)(%)', '총포괄이익증가율(전년동기)(%)', 'EBITDA증가율(전년동기)(%)',
       '총자산증가율(전년동기)(%)', '총부채증가율(전년동기)(%)', '총자본증가율(전년동기)(%)',
       'EPS증가율(전년동기)(%)', 'BPS증가율(전년동기)(%)', 'ROA(총포괄이익)(%)', 'ROE(당기순이익)(%)',
       '총자산회전율(회)', '현금및현금성자산구성비율(%)', '차입부채/EBITDA(배)', 'EBITDA(천원)',
       'CFPS(원)', 'P/EBITDAPS(배)', '변동성 (20일)', '거래량 (20일 평균)(주)',
       '외국인보유비중(보통+우선)(%)', '공매도거래량 (20일)(주)', '순매수수량(개인)(20일합산)(주)',
       '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)', 'PER(IFRS-연결)',
       'PBR(IFRS-연결)', 'PSR(IFRS-연결)']
    
    for i in range(0, len(cols)):
        df.iloc[:,i] = df.iloc[:,i].replace(0, np.NaN)
        df = df[~(np.abs(df.iloc[:,i] - df.iloc[:,i].mean()) > (3*df.iloc[:,i].std()))].fillna(0)
    
    return(df)

# %%
# ## box_plot 이용  np.percentile(a, 75) 이용해서 식 변경
# def std_based_outlier(df):
#     cols = ['부채비율(%)', '매출액증가율(전년동기)(%)', '매출총이익증가율(전년동기)(%)', '영업이익증가율(전년동기)(%)',
#        '당기순이익증가율(전년동기)(%)', '총포괄이익증가율(전년동기)(%)', 'EBITDA증가율(전년동기)(%)',
#        '총자산증가율(전년동기)(%)', '총부채증가율(전년동기)(%)', '총자본증가율(전년동기)(%)',
#        'EPS증가율(전년동기)(%)', 'BPS증가율(전년동기)(%)', 'ROA(총포괄이익)(%)', 'ROE(당기순이익)(%)',
#        '총자산회전율(회)', '현금및현금성자산구성비율(%)', '차입부채/EBITDA(배)', 'EBITDA(천원)',
#        'CFPS(원)', 'P/EBITDAPS(배)', '변동성 (20일)', '거래량 (20일 평균)(주)',
#        '외국인보유비중(보통+우선)(%)', '공매도거래량 (20일)(주)', '순매수수량(개인)(20일합산)(주)',
#        '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)', 'PER(IFRS-연결)',
#        'PBR(IFRS-연결)', 'PSR(IFRS-연결)']
    
#     for i in range(0, len(cols)):
#         df.iloc[:,i] = df.iloc[:,i].replace(0, np.NaN)
#         df = df[~(np.abs(df.iloc[:,i] - df.iloc[:,i].mean()) > (2*df.iloc[:,i].std()))].fillna(0)
    
#     return(df)

# %%
## 증가율로 바꾸기 / null값 지우기 등.. 실행
def preprocessing_data(data): 
    # 쓸 변수 선택
    data = data[['부채비율(%)', '매출액증가율(전년동기)(%)', '매출총이익증가율(전년동기)(%)', '영업이익증가율(전년동기)(%)',
       '당기순이익증가율(전년동기)(%)', '총포괄이익증가율(전년동기)(%)', 'EBITDA증가율(전년동기)(%)',
       '총자산증가율(전년동기)(%)', '총부채증가율(전년동기)(%)', '총자본증가율(전년동기)(%)',
       'EPS증가율(전년동기)(%)', 'BPS증가율(전년동기)(%)', 'ROA(총포괄이익)(%)', 'ROE(당기순이익)(%)',
       '총자산회전율(회)', '현금및현금성자산구성비율(%)', '차입부채/EBITDA(배)', 'EBITDA(천원)',
       'CFPS(원)', 'P/EBITDAPS(배)', '변동성 (20일)', '거래량 (20일 평균)(주)',
       '외국인보유비중(보통+우선)(%)', '공매도거래량 (20일)(주)', '순매수수량(개인)(20일합산)(주)',
       '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)', 'PER(IFRS-연결)',
       'PBR(IFRS-연결)', 'PSR(IFRS-연결)','수익률 (3개월)(%)', 'Name', '거래정지구분']]
    
    col_name = data.columns
    company_name = data.Name
    scaled_total_dataset = pd.DataFrame()

    for name in list(set(company_name)):
        
        ## 회사 별로 뽑아오기
        sub_dataset = data[data.Name == name]
        
        #거래정지구분에서 null 값있는 row 제거(상장 전 기간 제거)
        select_notNan = sub_dataset['거래정지구분'].dropna()
        sub_dataset = sub_dataset.loc[select_notNan.index]
        
        # 거래정지 로우 & 칼럼 제거
        sub_dataset = sub_dataset[sub_dataset['거래정지구분'] !='거래정지']
        sub_dataset.drop(['거래정지구분'],inplace=True,axis=1)
        
#         #결측치 처리 구간 ***********************************************************************
#         per, psr, pbr => null은 칼럼 평균으로 대체 
#         sub_dataset['PER(IFRS-연결)'].fillna(sub_dataset['PER(IFRS-연결)'].mean(),inplace = True)
#         sub_dataset['PSR(IFRS-연결)'].fillna(sub_dataset['PSR(IFRS-연결)'].mean(),inplace = True)
#         sub_dataset['PBR(IFRS-연결)'].fillna(sub_dataset['PBR(IFRS-연결)'].mean(),inplace = True)
        
        # 변화율로 만들기
        sub_dataset = making_rate_of_change(sub_dataset,['부채비율(%)', 'ROA(총포괄이익)(%)', 'ROE(당기순이익)(%)',
       '총자산회전율(회)', '현금및현금성자산구성비율(%)', '차입부채/EBITDA(배)', 'EBITDA(천원)',
       'CFPS(원)', 'P/EBITDAPS(배)', '변동성 (20일)', '거래량 (20일 평균)(주)','외국인보유비중(보통+우선)(%)', 
       '공매도거래량 (20일)(주)', '순매수수량(개인)(20일합산)(주)',
       '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)', 'PER(IFRS-연결)','PBR(IFRS-연결)', 'PSR(IFRS-연결)'])

        
        ## 수익률 없는 칼럼 삭제
        sub_dataset = sub_dataset[sub_dataset['수익률 (3개월)(%)'].isna() == False]
        
            ## inf 처리
        for i in sub_dataset.columns:
            sub_dataset = sub_dataset.loc[sub_dataset[i] != np.inf]
        
        ### 이상치 처리 ## ************************************************************************************        
        sub_dataset = std_based_outlier(sub_dataset)
        
#        #스케일링
#         sub_dataset = scaling_data(sub_dataset)
        
        scaled_total_dataset = scaled_total_dataset.append(sub_dataset)

    
    scaled_total_dataset = scaled_total_dataset[scaled_total_dataset['수익률 (3개월)(%)'] < 60]
    scaled_total_dataset = scaled_total_dataset[scaled_total_dataset['수익률 (3개월)(%)'] > -60 ]

    ### 수익률 변환
    scaled_total_dataset['3개월 수익률(4)'] = make_cate_f(scaled_total_dataset)
    scaled_total_dataset['3개월 수익률(2)'] = make_cate_t(scaled_total_dataset) 


    ## 결측치 있는 행 삭제 2174 -> 1846 로우 축소
    scaled_total_dataset.dropna(axis=0,inplace=True)
    
    scaled_total_dataset = scaled_total_dataset[['부채비율(%)', '매출액증가율(전년동기)(%)', '매출총이익증가율(전년동기)(%)', '영업이익증가율(전년동기)(%)',
       '당기순이익증가율(전년동기)(%)', '총포괄이익증가율(전년동기)(%)', 'EBITDA증가율(전년동기)(%)',
       '총자산증가율(전년동기)(%)', '총부채증가율(전년동기)(%)', '총자본증가율(전년동기)(%)',
       'EPS증가율(전년동기)(%)', 'BPS증가율(전년동기)(%)', 'ROA(총포괄이익)(%)', 'ROE(당기순이익)(%)',
       '총자산회전율(회)', '현금및현금성자산구성비율(%)', '차입부채/EBITDA(배)', 'EBITDA(천원)',
       'CFPS(원)', 'P/EBITDAPS(배)', '변동성 (20일)', '거래량 (20일 평균)(주)',
       '외국인보유비중(보통+우선)(%)', '공매도거래량 (20일)(주)', '순매수수량(개인)(20일합산)(주)',
       '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)', 'PER(IFRS-연결)',
       'PBR(IFRS-연결)', 'PSR(IFRS-연결)', '부채비율(%)변화율',
       'ROA(총포괄이익)(%)변화율', 'ROE(당기순이익)(%)변화율', '총자산회전율(회)변화율',
       '현금및현금성자산구성비율(%)변화율', '차입부채/EBITDA(배)변화율', 'EBITDA(천원)변화율',
       'CFPS(원)변화율', 'P/EBITDAPS(배)변화율', '변동성 (20일)변화율', '거래량 (20일 평균)(주)변화율',
       '외국인보유비중(보통+우선)(%)변화율', '공매도거래량 (20일)(주)변화율', '순매수수량(개인)(20일합산)(주)변화율',
       '순매수수량(기관계)(20일합산)(주)변화율', '순매수수량(외국인계)(20일합산)(주)변화율',
       'PER(IFRS-연결)변화율', 'PBR(IFRS-연결)변화율', 'PSR(IFRS-연결)변화율', 'Name','수익률 (3개월)(%)','3개월 수익률(4)',
       '3개월 수익률(2)']]

    return scaled_total_dataset

# %%
dataset = preprocessing_data(merged_Data)

# %%
len(dataset)
# Out:
# 1843

# %%
dataset.to_excel('./null_deleted_dataset.xlsx',encoding='utf-8')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import platform
from matplotlib import font_manager, rc

plt.rcParams['axes.unicode_minus'] = False
if platform.system() == 'Darwin':    # 맥
    rc( 'font', family='AppleGothic' )
elif platform.system() == 'Windows': # 윈도우
    fontPath = 'c:/Windows/Fonts/malgun.ttf'
    fontName = font_manager.FontProperties( fname=fontPath ).get_name()
    rc( 'font', family=fontName )
else:
    print('알수없는 시스템. 미적용')
    
pd.set_option('display.expand_frame_repr', False)
import warnings
warnings.filterwarnings(action='ignore')

# %%
for i in dataset.columns[:-4]:
        sns.kdeplot(data=dataset[dataset['3개월 수익률(2)'] == 1][i])
        sns.kdeplot(data=dataset[dataset['3개월 수익률(2)'] == 0][i])
        plt.title([i])
        plt.show()
