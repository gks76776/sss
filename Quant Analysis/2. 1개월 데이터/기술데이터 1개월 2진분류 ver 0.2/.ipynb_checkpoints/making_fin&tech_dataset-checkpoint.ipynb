# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import scale
from sklearn import metrics

# %%
data = pd.read_excel('./월별 기술데이터.xlsx')

# %%
# 회사별로 reshape  20
def reshape_fin_dataset(data):
    ##  쓸데없는 칼럼 제거
    company_name = list((data.iloc[8]))
    col_name = list(data.iloc[11])
    data = data.iloc[13:]
    data.columns = col_name
    col_num = len(list(set(col_name)))
    dummy = pd.DataFrame([np.nan])
    # 더미 데이터셋 생성
    sets = pd.DataFrame()    
    for i in range(len(set(company_name))):
        ## 회사 별로 뽑아오기
        sub_dataset = data.iloc[:,i*col_num : (i+1)*col_num][:-1]
        sub_dataset['Name'] = company_name[i*col_num]
        sub_revenue = sub_dataset['수익률 (1개월)(%)'][1:]
        sub_revenue = sub_revenue.append(dummy)
        sub_revenue.index = sub_dataset.index
        sub_dataset['수익률 (1개월)(%)'] = sub_revenue
        sets = sets.append(sub_dataset)

    return sets

# %%
# 2013년 9월 ~ 2018 년 6월 완료
tech = reshape_fin_dataset(data)
tech
# Out:
#            거래정지구분 수익률(%) 수익률 (1주)(%) 수익률 (1개월)(%) 수익률 (3개월)(%) 변동성 (5일)  \
# 2010-01-31     정상  -2.97       -4.97         9.95         9.19   0.0239
# 2010-02-28     정상   1.09       -2.11          4.3         0.13   0.0175
# 2010-03-31     정상   0.49       -0.12         -8.6         2.38   0.0037
# 2010-04-30     정상   2.91        2.29        -0.51         8.29   0.0151
# 2010-05-31     정상  -0.26        2.37         4.65          4.3   0.0191
# 2010-06-30     정상  -2.27       -3.85        -6.67        -4.91   0.0162
# 2010-07-31     정상  -2.06       -0.12         0.13        -4.59   0.0151
# 2010-08-31     정상  -2.58       -3.45         -3.5        -2.58   0.0148
# 2010-09-30     정상   0.65       -0.38        10.87         0.39   0.0231
# 2010-10-31     정상  -2.49       -4.12        14.89        -9.92   0.0144
# 2010-11-30     정상   -1.2       -1.67         3.37         6.44     0.01
# 2010-12-31     정상   0.42        1.39        -8.61        22.14    0.011
# 2011-01-31     정상  -2.87        1.03         0.98        31.68   0.0203
# 2011-02-28     정상  -0.32       -2.64        -2.51        10.27    0.004
# 2011-03-31     정상   0.65        5.91         1.01        -1.79   0.0132
# 2011-04-30     정상  -0.78       -1.22        -6.56       -11.58   0.0222
# 2011-05-31     정상   2.04        4.28         1.32        -2.28   0.0168
# 2011-06-30     정상  -0.84        -0.6       -11.85        -10.8   0.0167
# 2011-07-31     정상   0.84       -0.71        13.21        -5.49   0.0073
# 2011-08-31     정상   0.27        5.08        15.24       -17.52   0.0091
# 2011-09-30     정상   0.36       10.82         6.24         1.69   0.0168
# 2011-10-31     정상   2.43        2.87         5.27        14.69   0.0174
# 2011-11-30     정상   -0.1        7.38         4.63        35.31   0.0149
# 2011-12-31     정상  -0.28        0.57          7.2         26.4   0.0101
# 2012-01-31     정상  -0.72        0.18         5.72        14.36   0.0089
# 2012-02-29     정상   1.77        0.75         9.02           20   0.0209
# 2012-03-31     정상  -0.39        1.11       -12.88        20.51   0.0176
# 2012-04-30     정상   1.16        8.68        -2.99        24.66   0.0099
# 2012-05-31     정상  -1.22       -1.14         8.99         0.41   0.0094
# 2012-06-30     정상   2.83        1.61        -5.81        -6.17   0.0282
# ...           ...    ...         ...          ...          ...      ...
# 2016-09-30               -12227               -233299          NaN
# 2016-10-31                65506                206813          NaN
# 2016-11-30              -123231                401156          NaN
# 2016-12-31              -204817               -516139          NaN
# 2017-01-31              -447785              -1042757          NaN
# 2017-02-28               -37037               -239161          NaN
# 2017-03-31              -286026               -718422          NaN
# 2017-04-30              -543032              -1822423          NaN
# 2017-05-31               348085               -719513          NaN
# 2017-06-30               -12265               -369785          NaN
# 2017-07-31              -139723               -114515          NaN
# 2017-08-31               825464                802066          NaN
# 2017-09-30               -71440              -1505564          NaN
# 2017-10-31               104474                565728          NaN
# 2017-11-30               353788                597865          NaN
# 2017-12-31               332574                469255          NaN
# 2018-01-31               559765               1724965          NaN
# 2018-02-28               250720                481747          NaN
# 2018-03-31               -30630                126446          NaN
# 2018-04-30               -44937                158574          NaN
# 2018-05-31                -2908               -272212          NaN
# 2018-06-30               -61819               -314506          NaN
# 2018-07-31               107093                316127          NaN
# 2018-08-31               210373                444010          NaN
# 2018-09-30                86106                135780          NaN
# 2018-10-31               219023                559960          NaN
# 2018-11-30              -283087              -1545359          NaN
#
#            PBR(IFRS-연결) PSR(IFRS-연결) PCR(IFRS-연결)   Name
# 2010-01-31         1.71         0.98         6.44   삼성전자
# 2010-02-28         1.62         0.93         6.11   삼성전자
# 2010-03-31         1.78         1.02         6.72   삼성전자
# 2010-04-30         1.85         1.06         6.97   삼성전자
# 2010-05-31         1.69         0.97         6.38   삼성전자
# 2010-06-30         1.69         0.97         6.36   삼성전자
# 2010-07-31         1.77         1.01         6.65   삼성전자
# 2010-08-31         1.65         0.94         6.21   삼성전자
# 2010-09-30          1.7         0.97         6.38   삼성전자
# 2010-10-31         1.63         0.93         6.12   삼성전자
# 2010-11-30          1.8         1.03         6.79   삼성전자
# 2010-12-31         2.07         1.18          7.8   삼성전자
# 2011-01-31         1.79         1.08         6.14   삼성전자
# 2011-02-28         1.68         1.02         5.77   삼성전자
# 2011-03-31          1.7         1.03         5.83   삼성전자
# 2011-04-30         1.63         0.98         5.59   삼성전자
# 2011-05-31         1.64         0.99         5.64   삼성전자
# 2011-06-30         1.51         0.91         5.17   삼성전자
# 2011-07-31         1.54         0.93         5.28   삼성전자
# 2011-08-31         1.36         0.82         4.65   삼성전자
# 2011-09-30         1.53         0.92         5.26   삼성전자
# 2011-10-31         1.76         1.07         6.06   삼성전자
# 2011-11-30         1.83          1.1         6.28   삼성전자
# 2011-12-31         1.93         1.16         6.62   삼성전자
# 2012-01-31          1.8         1.14         6.98   삼성전자
# 2012-02-29         1.96         1.24         7.61   삼성전자
# 2012-03-31         2.07         1.31         8.04   삼성전자
# 2012-04-30         2.26         1.43         8.77   삼성전자
# 2012-05-31         1.97         1.25         7.64   삼성전자
# 2012-06-30         1.95         1.24         7.57   삼성전자
# ...                 ...          ...          ...    ...
# 2016-06-30         0.34         0.13          NaN  한진중공업
# 2016-07-31         0.39         0.15          NaN  한진중공업
# 2016-08-31         0.37         0.14          NaN  한진중공업
# 2016-09-30         0.37         0.14          NaN  한진중공업
# 2016-10-31         0.34         0.13          NaN  한진중공업
# 2016-11-30         0.29         0.11          NaN  한진중공업
# 2016-12-31         0.29         0.11          NaN  한진중공업
# 2017-01-31         0.35         0.11          NaN  한진중공업
# 2017-02-28         0.37         0.12          NaN  한진중공업
# 2017-03-31         0.46         0.14          NaN  한진중공업
# 2017-04-30          0.4         0.12          NaN  한진중공업
# 2017-05-31          0.5         0.16          NaN  한진중공업
# 2017-06-30         0.53         0.17          NaN  한진중공업
# 2017-07-31         0.52         0.16          NaN  한진중공업
# 2017-08-31         0.56         0.17          NaN  한진중공업
# 2017-09-30         0.45         0.14          NaN  한진중공업
# 2017-10-31         0.45         0.14          NaN  한진중공업
# 2017-11-30         0.44         0.14          NaN  한진중공업
# 2017-12-31         0.39         0.12          NaN  한진중공업
# 2018-01-31         0.44         0.14          NaN  한진중공업
# 2018-02-28          0.4         0.12          NaN  한진중공업
# 2018-03-31         0.57         0.14          NaN  한진중공업
# 2018-04-30         0.62         0.15          NaN  한진중공업
# 2018-05-31         0.61         0.14          NaN  한진중공업
# 2018-06-30         0.55         0.13          NaN  한진중공업
# 2018-07-31         0.51         0.12          NaN  한진중공업
# 2018-08-31         0.48         0.11          NaN  한진중공업
# 2018-09-30         0.47         0.11          NaN  한진중공업
# 2018-10-31         0.32         0.08          NaN  한진중공업
# 2018-11-30         0.31         0.07          NaN  한진중공업
#
# [15943 rows x 45 columns]

# %%
def making_rate_of_change(sub_dataset,col):
    # 변화율 칼럼 삽입 / 기존 칼럼 삭제*********************************************************************
    for colname in col:
        # 변화율 백터 생성
        a = sub_dataset[colname]
        g = list(a.pct_change())

        ## 분보가 - 일때 방향성이 달라져서 -1 곱하기
        for i in list(range(len(a)))[:-1]:
            if list(a)[i] < 0:
                g[i+1] = g[i+1] * (-1)
                
            elif list(a)[i] == 0:
                g[i+1] = np.nan
                    
        sub_dataset[colname+'변화율'] = g
        
    return sub_dataset

# %%
def scaling_data(sub_set):
    scaled_data = pd.DataFrame()

    sub_set = sub_set.iloc[1:]
    sub_set_y = sub_set.index
    
    scale_col = ['변동성 (20일)', '거래량 (20일 평균)(주)', '외국인보유비중(보통+우선)(%)', '공매도거래량 (20일)(주)',
                   '순매수수량(개인)(20일합산)(주)', '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)',
                   'PER(IFRS-연결)', 'PBR(IFRS-연결)', 'PSR(IFRS-연결)']
    
    unscale_col = ['변동성 (20일)변화율', '외국인보유비중(보통+우선)(%)변화율','PER(IFRS-연결)변화율',
                   'PBR(IFRS-연결)변화율', 'PSR(IFRS-연결)변화율', '수익률 (1개월)(%)','Name']
    
    sub_set_x = sub_set[scale_col]
    sub_set_no = sub_set[unscale_col]
    
    ## 스케일 부분
    scaled_sub_set_x = pd.DataFrame(scale(sub_set_x),index = sub_set_y ,columns = scale_col)
    x = pd.concat([scaled_sub_set_x,sub_set_no],axis = 1)
    
    return x

# %%
def make_cate_t(data):
    ## 수익률 범주화
    bb = np.array([-100,0,100])

    Y_data_cat = np.digitize(data['수익률 (1개월)(%)'],bb)
    Y_data_cat = Y_data_cat - 1
    
    return Y_data_cat

# %%
def make_cate_f(data):
    ## 수익률 범주화
    bb = np.array([-100,-15,0,15,100])

    Y_data_cat = np.digitize(data['수익률 (1개월)(%)'],bb)
    Y_data_cat = Y_data_cat - 1
    
    return Y_data_cat

# %%
## 표춘편차 이용
def std_based_outlier(df):
    cols = []
    
    for i in range(0, len(cols)):
        df.iloc[:,i] = df.iloc[:,i].replace(0, np.NaN)
        df = df[~(np.abs(df.iloc[:,i] - df.iloc[:,i].mean()) > (3*df.iloc[:,i].std()))].fillna(0)
    
    return(df)

# %%
## 증가율로 바꾸기 / null값 지우기 등.. 실행
def preprocessing_data(data):    
    col_name = data.columns
    company_name = data.Name
    scaled_total_dataset = pd.DataFrame()

    for name in list(set(company_name)):
        
        ## 회사 별로 뽑아오기
        sub_dataset = data[data.Name == name]
        
        #거래정지구분에서 null 값있는 row 제거(상장 전 기간 제거)
        select_notNan = sub_dataset['거래정지구분'].dropna()
        sub_dataset = sub_dataset.loc[select_notNan.index]
        
        # 거래정지 로우 & 칼럼 제거
        sub_dataset = sub_dataset[sub_dataset['거래정지구분'] !='거래정지']
        sub_dataset.drop(['거래정지구분'],inplace=True,axis=1)
        
#         #결측치 처리 구간 ***********************************************************************
#         per, psr, pbr => null은 칼럼 평균으로 대체 
#         sub_dataset['PER(IFRS-연결)'].fillna(sub_dataset['PER(IFRS-연결)'].mean(),inplace = True)
#         sub_dataset['PSR(IFRS-연결)'].fillna(sub_dataset['PSR(IFRS-연결)'].mean(),inplace = True)
#         sub_dataset['PBR(IFRS-연결)'].fillna(sub_dataset['PBR(IFRS-연결)'].mean(),inplace = True)
        
        # 변화율로 만들기
        sub_dataset = making_rate_of_change(sub_dataset,['변동성 (20일)', '외국인보유비중(보통+우선)(%)',
       'PER(IFRS-연결)', 'PBR(IFRS-연결)', 'PSR(IFRS-연결)'])

        
        ## 수익률 없는 칼럼 삭제
        sub_dataset = sub_dataset[sub_dataset['수익률 (1개월)(%)'].isna() == False]
        
            ## inf 처리
#         for i in sub_dataset.columns:
#             sub_dataset = sub_dataset.loc[sub_dataset[i] != np.inf]
        
        ### 이상치 처리 ## ************************************************************************************        
        sub_dataset = std_based_outlier(sub_dataset)
        
#        #스케일링
        sub_dataset = scaling_data(sub_dataset)
        
        scaled_total_dataset = scaled_total_dataset.append(sub_dataset)

    
    scaled_total_dataset = scaled_total_dataset[scaled_total_dataset['수익률 (1개월)(%)'] < 50]
    scaled_total_dataset = scaled_total_dataset[scaled_total_dataset['수익률 (1개월)(%)'] > -50 ]

    ### 수익률 변환
    scaled_total_dataset['1개월 수익률(4)'] = make_cate_f(scaled_total_dataset)
    scaled_total_dataset['1개월 수익률(2)'] = make_cate_t(scaled_total_dataset) 


    ## 결측치 있는 행 삭제 2174 -> 1775 로우 축소
    scaled_total_dataset.dropna(axis=0,inplace=True)
    
    scaled_total_dataset = scaled_total_dataset[['변동성 (20일)', '거래량 (20일 평균)(주)', '외국인보유비중(보통+우선)(%)',
   '공매도거래량 (20일)(주)','순매수수량(개인)(20일합산)(주)', '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)',
   'PER(IFRS-연결)', 'PBR(IFRS-연결)', 'PSR(IFRS-연결)','변동성 (20일)변화율','외국인보유비중(보통+우선)(%)변화율', 'PER(IFRS-연결)변화율',
   'PBR(IFRS-연결)변화율', 'PSR(IFRS-연결)변화율', '수익률 (1개월)(%)','1개월 수익률(4)', '1개월 수익률(2)','Name']]

    return scaled_total_dataset

# %%
dataset = preprocessing_data(tech)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:161: RuntimeWarning: Mean of empty slice
#   mean_ = np.nanmean(X, axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\nanfunctions.py:1545: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:169: RuntimeWarning: Mean of empty slice
#   mean_1 = np.nanmean(Xr, axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:176: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:186: RuntimeWarning: Mean of empty slice
#   mean_2 = np.nanmean(Xr, axis=0)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:193: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn("Numerical issues were encountered "
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DataConversionWarning: Data with input dtype object were all converted to float64 by the scale function.

# %%
dataset.columns
# Out:
# Index(['변동성 (20일)', '거래량 (20일 평균)(주)', '외국인보유비중(보통+우선)(%)', '공매도거래량 (20일)(주)',
#        '순매수수량(개인)(20일합산)(주)', '순매수수량(기관계)(20일합산)(주)', '순매수수량(외국인계)(20일합산)(주)',
#        'PER(IFRS-연결)', 'PBR(IFRS-연결)', 'PSR(IFRS-연결)', '변동성 (20일)변화율',
#        '외국인보유비중(보통+우선)(%)변화율', 'PER(IFRS-연결)변화율', 'PBR(IFRS-연결)변화율',
#        'PSR(IFRS-연결)변화율', '수익률 (1개월)(%)', '1개월 수익률(4)', '1개월 수익률(2)', 'Name'],
#       dtype='object')

# %%
dataset.to_excel('./non_out_data.xlsx',encoding='utf-8')
